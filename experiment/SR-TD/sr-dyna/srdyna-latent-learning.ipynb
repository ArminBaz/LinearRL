# %%
import matplotlib.pyplot as plt
import numpy as np
import srdyna
import importlib

# %%
importlib.reload(srdyna)
# Out:
# <module 'srdyna' from '/Users/abizzle/Research/LinearRL/experiment/SR-TD/sr-dyna/srdyna.py'>

# %%
REPLAY = "sufficient"
EXPLORE_STEPS = 25000
POST_REWARD_STEPS = 20
REPLAY_STEPS = {
    "insufficient": 10,
    "sufficient": 10000
}[REPLAY]
env = srdyna.SimpleGridWorld(world='worlds/latent_learning.txt')
agent = srdyna.SRDyna(id=0, loc=(0, 2), env=env)

R1_LOC = (9, 8)
env.add_reward(R1_LOC, 0)  # Initially empty, but terminates

# Explore
for i in range(EXPLORE_STEPS):
    agent.step(random_policy=True)

# Increase reward
env.reward_locs[R1_LOC]['reward'] = 10  

# One-step replay samples from random sa's
agent.learn_offline(k=REPLAY_STEPS)

for i in range(POST_REWARD_STEPS):
    # Repeated one-step runs from R1
    agent.terminate_episode(reset_state=env.state_at_loc(R1_LOC))
    agent.step(verbose=False)

agent.make_plots(sr_state=9)

# One-step replay samples from random sa's
# agent.learn_offline(k=REPLAY_STEPS)
    
agent.make_plots(sr_state=9)
# Out:
# Loaded 10x10 world with 102 states
# (9, 8)
# (9, 8)
# (9, 8)
# (9, 8)
# (9, 8)
# (9, 8)

# %%
agent.make_plots(sr_state=agent.env.state_at_loc((0,2)))
# Out:
# (9, 8)
# (9, 8)
# (9, 8)

# %%
sr_state=9
sa_idx = agent.state_action_index(sr_state, 0)
state_sr = agent.H[sa_idx:sa_idx+4].sum(axis=0)[:agent.n_viz_sas()].reshape(-1, 4).max(axis=1)

# %%
agent.H.shape
# Out:
# (402, 402)

# %%
print(agent.H[sa_idx:sa_idx+4].sum(axis=0)[:agent.n_viz_sas()].reshape(-1, 4).shape)
# Out:
# (100, 4)
